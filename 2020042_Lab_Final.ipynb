# %%
import pandas as pd

df = pd.read_excel('/Users/student/Downloads/chatgpt1.xlsx')
print(df)
# Out:
#                         Datetime             Tweet Id  \
# 0      2023-01-22 13:44:34+00:00  1617156270871689984
# 1      2023-01-22 13:44:39+00:00  1617156291046129920
# 2      2023-01-22 13:44:44+00:00  1617156308926340096
# 3      2023-01-22 13:44:49+00:00  1617156332297250048
# 4      2023-01-22 13:44:52+00:00  1617156345064570112
# ...                          ...                  ...
# 49996  2023-01-24 06:57:56+00:00  1617778712082089984
# 49997  2023-01-24 06:57:59+00:00  1617778726393240064
# 49998  2023-01-24 06:58:00+00:00  1617778728481989888
# 49999  2023-01-24 06:58:01+00:00  1617778731678040064
# 50000  2023-01-24 06:58:01+00:00  1617778733355790080
#
#                                                     Text         Username  \
# 0      ChatGPTã§éŠã¶ã®å¿˜ã‚Œã¦ãŸï¼ï¼\næ›¸é¡žä...      mochico0123
# 1      @AlexandrovnaIng Prohibition of ChatGPT has be...  Caput_LupinumSG
# 2      Schaut Euch an, was @fobizz @DianaKnodel alles...            ciffi
# 3      Bow down to chatGPT ðŸ«¡..... https://t.co/ENT...    Vishwasrisiri
# 4      Profilinde vatan, TÃ¼rkiye falan yazan bireyle...   0xGenetikciniz
# ...                                                  ...              ...
# 49996  #ChatGPT ist ein #Chatbot, der durch kÃ¼nstlic...     HorstKrieger
# 49997  @r8r Ich hab mal die AI dazu befragt (ChatGPT)...            werpu
# 49998  5 minuti di #chatGPT e ho capito che apprende ...   marcopiccinini
# 49999  Portland Shop Uses ChatGPT To Tell Family Stor...    EuniceNyandat
# 50000  Ahora sueÃ±o con el dÃ­a en que Amazon integre...     AmericoSD_69
#
#                                                Permalink  \
# 0      https://twitter.com/mochico0123/status/1617156...
# 1      https://twitter.com/Caput_LupinumSG/status/161...
# 2      https://twitter.com/ciffi/status/1617156308926...
# 3      https://twitter.com/Vishwasrisiri/status/16171...
# 4      https://twitter.com/0xGenetikciniz/status/1617...
# ...                                                  ...
# 49996  https://twitter.com/HorstKrieger/status/161777...
# 49997  https://twitter.com/werpu/status/1617778726393...
# 49998  https://twitter.com/marcopiccinini/status/1617...
# 49999  https://twitter.com/EuniceNyandat/status/16177...
# 50000  https://twitter.com/AmericoSD_69/status/161777...
#
#                                       User  \
# 0          https://twitter.com/mochico0123
# 1      https://twitter.com/Caput_LupinumSG
# 2                https://twitter.com/ciffi
# 3        https://twitter.com/Vishwasrisiri
# 4       https://twitter.com/0xGenetikciniz
# ...                                    ...
# 49996     https://twitter.com/HorstKrieger
# 49997            https://twitter.com/werpu
# 49998   https://twitter.com/marcopiccinini
# 49999    https://twitter.com/EuniceNyandat
# 50000     https://twitter.com/AmericoSD_69
#
#                                                 Outlinks  \
# 0                                                    NaN
# 1                                                    NaN
# 2      ['https://us02web.zoom.us/webinar/register/801...
# 3      ['https://twitter.com/agadmator/status/1617155...
# 4                                                    NaN
# ...                                                  ...
# 49996  ['https://lnkd.in/dzHbz5-z', 'https://lnkd.in/...
# 49997                                                NaN
# 49998                                                NaN
# 49999                     ['https://drumup.io/s/DkswB6']
# 50000                                                NaN
#
#                                               CountLinks  ReplyCount  \
# 0                                                    NaN           1
# 1                                                    NaN           1
# 2      ['https://t.co/DsoeVJrPBp', 'https://t.co/HflT...           0
# 3                            ['https://t.co/ENTSzi2AQ9']           0
# 4                                                    NaN           0
# ...                                                  ...         ...
# 49996  ['https://t.co/qxUJZinuNO', 'https://t.co/lFZD...           0
# 49997                                                NaN           0
# 49998                                                NaN           0
# 49999                        ['https://t.co/rzGvr6yTOc']           0
# 50000                                                NaN           0
#
#        RetweetCount  LikeCount  QuoteCount       ConversationId Language  \
# 0                 0          5           0  1617156270871689984       ja
# 1                 0          5           0  1617148639993799936       en
# 2                 0          4           0  1617156308926340096       de
# 3                 0          2           0  1617156332297250048       en
# 4                 0          4           0  1617156345064570112       tr
# ...             ...        ...         ...                  ...      ...
# 49996             0          0           0  1617778712082089984       de
# 49997             0          0           0  1617774521586700032       de
# 49998             0          0           0  1617778728481989888       it
# 49999             0          0           0  1617778731678040064       en
# 50000             0          0           0  1617778733355790080       es
#
#                                                   Source  \
# 0      <a href="http://twitter.com/download/iphone" r...
# 1      <a href="http://twitter.com/download/iphone" r...
# 2      <a href="http://twitter.com/#!/download/ipad" ...
# 3      <a href="http://twitter.com/download/android" ...
# 4      <a href="http://twitter.com/download/iphone" r...
# ...                                                  ...
# 49996  <a href="http://www.linkedin.com/" rel="nofoll...
# 49997  <a href="https://mobile.twitter.com" rel="nofo...
# 49998  <a href="http://twitter.com/download/iphone" r...
# 49999  <a href="https://drumup.io" rel="nofollow">dru...
# 50000  <a href="http://twitter.com/download/android" ...
#
#                                                    Media  \
# 0                                                    NaN
# 1                                                    NaN
# 2      [Photo(previewUrl='https://pbs.twimg.com/media...
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 49996                                                NaN
# 49997  [Photo(previewUrl='https://pbs.twimg.com/media...
# 49998  [Photo(previewUrl='https://pbs.twimg.com/media...
# 49999                                                NaN
# 50000                                                NaN
#
#                                              QuotedTweet  \
# 0                                                    NaN
# 1                                                    NaN
# 2      https://twitter.com/DianaKnodel/status/1617153...
# 3      https://twitter.com/agadmator/status/161715501...
# 4                                                    NaN
# ...                                                  ...
# 49996                                                NaN
# 49997                                                NaN
# 49998                                                NaN
# 49999                                                NaN
# 50000                                                NaN
#
#                                           MentionedUsers  \
# 0                                                    NaN
# 1      [User(username='AlexandrovnaIng', id=282705900...
# 2      [User(username='fobizz', id=884708145792253952...
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 49996                                                NaN
# 49997  [User(username='r8r', id=15451529, displayname...
# 49998                                                NaN
# 49999                                                NaN
# 50000                                                NaN
#
#                                                  hashtag  hastag_counts
# 0                                                     []              0
# 1                                                     []              0
# 2                                           ['#ChatGPT']              1
# 3                                                     []              0
# 4                                                     []              0
# ...                                                  ...            ...
# 49996  ['#ChatGPT', '#Chatbot,', '#KI', '#AI', '#Dial...              6
# 49997                                                 []              0
# 49998                                       ['#chatGPT']              1
# 49999                                                 []              0
# 50000                                                 []              0
#
# [50001 rows x 20 columns]

# %%
#Creating a function that takes care of all the preprocessing stuff.
def preprocess():

  df['Text'] = df['Text'].str.lower() # Ensuring all words in the Tweet column of training data are lowercased

  # Parsing the stop_words.txt file and storing all the words in a list.
  stopwords = []
  with open('/Users/student/Downloads/chatgpt1.xlsx',encoding='latin-1') as file:    
      for line in file:         
          for word in line.split():            
              stopwords.append(word)

  # Removing all stopwords from all the tweets in training data.
  #df["Text"] = df["Text"].apply(lambda func: ' '.join(sw 
   #                                         for sw in func.split() 
    #                                        if sw not in stopwords))
  #Training Data
  df['Text'] = df['Text'].str.replace(r'http?://[^\s<>"]+|www\.[^\s<>"]+', '') # Removing hyperlinks from all the tweets
  df['Text'] = df['Text'].str.replace('@[A-Za-z0-9]+', '') # Removing usernames from all the tweets.
  df['Text'] = df['Text'].str.replace(r'\B#\w*[a-zA-Z]+\w*', '') # Removing hashtags, including the text, from all the tweets
  df['Text'] = df['Text'].str.replace('\d+', '') # Removing numbers from all the tweets

  special_chars = ["!",'"',"%","&","amp","'","(",")", "*","+",",","-",".",
                  "/",":",";","<","=",">","?","[","\\","]","^","_",
                  "`","{","|","}","~","–","@","#","$"]

  for c in special_chars:
      df['Text'] = df['Text'].str.replace(c,'') # Removing all special characters from all the tweets

# %%
preprocess()
# Out:
# /var/folders/g9/hkd92dbd5zn6plc65t5br2p40000gn/T/ipykernel_3867/2421558882.py:18: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Text'] = df['Text'].str.replace(r'http?://[^\s<>"]+|www\.[^\s<>"]+', '') # Removing hyperlinks from all the tweets
# /var/folders/g9/hkd92dbd5zn6plc65t5br2p40000gn/T/ipykernel_3867/2421558882.py:19: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Text'] = df['Text'].str.replace('@[A-Za-z0-9]+', '') # Removing usernames from all the tweets.
# /var/folders/g9/hkd92dbd5zn6plc65t5br2p40000gn/T/ipykernel_3867/2421558882.py:20: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Text'] = df['Text'].str.replace(r'\B#\w*[a-zA-Z]+\w*', '') # Removing hashtags, including the text, from all the tweets
# /var/folders/g9/hkd92dbd5zn6plc65t5br2p40000gn/T/ipykernel_3867/2421558882.py:21: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Text'] = df['Text'].str.replace('\d+', '') # Removing numbers from all the tweets
# /var/folders/g9/hkd92dbd5zn6plc65t5br2p40000gn/T/ipykernel_3867/2421558882.py:28: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Text'] = df['Text'].str.replace(c,'') # Removing all special characters from all the tweets

# %%
print(df)
# Out:
#                         Datetime             Tweet Id  \
# 0      2023-01-22 13:44:34+00:00  1617156270871689984
# 1      2023-01-22 13:44:39+00:00  1617156291046129920
# 2      2023-01-22 13:44:44+00:00  1617156308926340096
# 3      2023-01-22 13:44:49+00:00  1617156332297250048
# 4      2023-01-22 13:44:52+00:00  1617156345064570112
# ...                          ...                  ...
# 49996  2023-01-24 06:57:56+00:00  1617778712082089984
# 49997  2023-01-24 06:57:59+00:00  1617778726393240064
# 49998  2023-01-24 06:58:00+00:00  1617778728481989888
# 49999  2023-01-24 06:58:01+00:00  1617778731678040064
# 50000  2023-01-24 06:58:01+00:00  1617778733355790080
#
#                                                     Text         Username  \
# 0      chatgptã§éšã¶ã®å¿˜ã‚œã¦ãÿï¼ï¼\næ›¸é¡žä...      mochico0123
# 1       prohibition of chatgpt has been added to the ...  Caput_LupinumSG
# 2      schaut euch an was   alles â¬‡ï¸ auf die pist...            ciffi
# 3              bow down to chatgpt ðÿ«¡ httpstcoentsziaq    Vishwasrisiri
# 4      profilinde vatan tã¼rkiye falan yazan bireyler...   0xGenetikciniz
# ...                                                  ...              ...
# 49996   ist ein  der durch kã¼nstliche intelligenz   ...     HorstKrieger
# 49997   ich hab mal die ai dazu befragt chatgpt https...            werpu
# 49998   minuti di  e ho capito che apprende in manier...   marcopiccinini
# 49999  portland shop uses chatgpt to tell family stor...    EuniceNyandat
# 50000  ahora sueã±o con el dã­a en que amazon integre...     AmericoSD_69
#
#                                                Permalink  \
# 0      https://twitter.com/mochico0123/status/1617156...
# 1      https://twitter.com/Caput_LupinumSG/status/161...
# 2      https://twitter.com/ciffi/status/1617156308926...
# 3      https://twitter.com/Vishwasrisiri/status/16171...
# 4      https://twitter.com/0xGenetikciniz/status/1617...
# ...                                                  ...
# 49996  https://twitter.com/HorstKrieger/status/161777...
# 49997  https://twitter.com/werpu/status/1617778726393...
# 49998  https://twitter.com/marcopiccinini/status/1617...
# 49999  https://twitter.com/EuniceNyandat/status/16177...
# 50000  https://twitter.com/AmericoSD_69/status/161777...
#
#                                       User  \
# 0          https://twitter.com/mochico0123
# 1      https://twitter.com/Caput_LupinumSG
# 2                https://twitter.com/ciffi
# 3        https://twitter.com/Vishwasrisiri
# 4       https://twitter.com/0xGenetikciniz
# ...                                    ...
# 49996     https://twitter.com/HorstKrieger
# 49997            https://twitter.com/werpu
# 49998   https://twitter.com/marcopiccinini
# 49999    https://twitter.com/EuniceNyandat
# 50000     https://twitter.com/AmericoSD_69
#
#                                                 Outlinks  \
# 0                                                    NaN
# 1                                                    NaN
# 2      ['https://us02web.zoom.us/webinar/register/801...
# 3      ['https://twitter.com/agadmator/status/1617155...
# 4                                                    NaN
# ...                                                  ...
# 49996  ['https://lnkd.in/dzHbz5-z', 'https://lnkd.in/...
# 49997                                                NaN
# 49998                                                NaN
# 49999                     ['https://drumup.io/s/DkswB6']
# 50000                                                NaN
#
#                                               CountLinks  ReplyCount  \
# 0                                                    NaN           1
# 1                                                    NaN           1
# 2      ['https://t.co/DsoeVJrPBp', 'https://t.co/HflT...           0
# 3                            ['https://t.co/ENTSzi2AQ9']           0
# 4                                                    NaN           0
# ...                                                  ...         ...
# 49996  ['https://t.co/qxUJZinuNO', 'https://t.co/lFZD...           0
# 49997                                                NaN           0
# 49998                                                NaN           0
# 49999                        ['https://t.co/rzGvr6yTOc']           0
# 50000                                                NaN           0
#
#        RetweetCount  LikeCount  QuoteCount       ConversationId Language  \
# 0                 0          5           0  1617156270871689984       ja
# 1                 0          5           0  1617148639993799936       en
# 2                 0          4           0  1617156308926340096       de
# 3                 0          2           0  1617156332297250048       en
# 4                 0          4           0  1617156345064570112       tr
# ...             ...        ...         ...                  ...      ...
# 49996             0          0           0  1617778712082089984       de
# 49997             0          0           0  1617774521586700032       de
# 49998             0          0           0  1617778728481989888       it
# 49999             0          0           0  1617778731678040064       en
# 50000             0          0           0  1617778733355790080       es
#
#                                                   Source  \
# 0      <a href="http://twitter.com/download/iphone" r...
# 1      <a href="http://twitter.com/download/iphone" r...
# 2      <a href="http://twitter.com/#!/download/ipad" ...
# 3      <a href="http://twitter.com/download/android" ...
# 4      <a href="http://twitter.com/download/iphone" r...
# ...                                                  ...
# 49996  <a href="http://www.linkedin.com/" rel="nofoll...
# 49997  <a href="https://mobile.twitter.com" rel="nofo...
# 49998  <a href="http://twitter.com/download/iphone" r...
# 49999  <a href="https://drumup.io" rel="nofollow">dru...
# 50000  <a href="http://twitter.com/download/android" ...
#
#                                                    Media  \
# 0                                                    NaN
# 1                                                    NaN
# 2      [Photo(previewUrl='https://pbs.twimg.com/media...
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 49996                                                NaN
# 49997  [Photo(previewUrl='https://pbs.twimg.com/media...
# 49998  [Photo(previewUrl='https://pbs.twimg.com/media...
# 49999                                                NaN
# 50000                                                NaN
#
#                                              QuotedTweet  \
# 0                                                    NaN
# 1                                                    NaN
# 2      https://twitter.com/DianaKnodel/status/1617153...
# 3      https://twitter.com/agadmator/status/161715501...
# 4                                                    NaN
# ...                                                  ...
# 49996                                                NaN
# 49997                                                NaN
# 49998                                                NaN
# 49999                                                NaN
# 50000                                                NaN
#
#                                           MentionedUsers  \
# 0                                                    NaN
# 1      [User(username='AlexandrovnaIng', id=282705900...
# 2      [User(username='fobizz', id=884708145792253952...
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 49996                                                NaN
# 49997  [User(username='r8r', id=15451529, displayname...
# 49998                                                NaN
# 49999                                                NaN
# 50000                                                NaN
#
#                                                  hashtag  hastag_counts
# 0                                                     []              0
# 1                                                     []              0
# 2                                           ['#ChatGPT']              1
# 3                                                     []              0
# 4                                                     []              0
# ...                                                  ...            ...
# 49996  ['#ChatGPT', '#Chatbot,', '#KI', '#AI', '#Dial...              6
# 49997                                                 []              0
# 49998                                       ['#chatGPT']              1
# 49999                                                 []              0
# 50000                                                 []              0
#
# [50001 rows x 20 columns]

# %%
#Feature and Label selection

y_col = 'Language'
y = df[y_col]

x_col = 'Text'
x = df[x_col]
y, x
# Out:
# (0        ja
#  1        en
#  2        de
#  3        en
#  4        tr
#           ..
#  49996    de
#  49997    de
#  49998    it
#  49999    en
#  50000    es
#  Name: Language, Length: 50001, dtype: object,
#  0        chatgptã§éšã¶ã®å¿˜ã‚œã¦ãÿï¼ï¼\næ›¸é¡žä...
#  1         prohibition of chatgpt has been added to the ...
#  2        schaut euch an was   alles â¬‡ï¸ auf die pist...
#  3                bow down to chatgpt ðÿ«¡ httpstcoentsziaq
#  4        profilinde vatan tã¼rkiye falan yazan bireyler...
#                                 ...
#  49996     ist ein  der durch kã¼nstliche intelligenz   ...
#  49997     ich hab mal die ai dazu befragt chatgpt https...
#  49998     minuti di  e ho capito che apprende in manier...
#  49999    portland shop uses chatgpt to tell family stor...
#  50000    ahora sueã±o con el dã­a en que amazon integre...
#  Name: Text, Length: 50001, dtype: object)

# %%
#Splitting into training and testing

training_data_x = x.sample(frac=0.8, random_state=25)
testing_data_x = x.drop(training_data_x.index)

training_data_y = y.sample(frac=0.8, random_state=25)
testing_data_y = y.drop(training_data_y.index)

print(f"No. of training examples: {training_data_x.shape[0]}")
print(f"No. of testing examples: {testing_data_x.shape[0]}")
# Out:
# No. of training examples: 40001
# No. of testing examples: 10000

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf = TfidfVectorizer()

# Assuming training_data_x is a pandas Series or DataFrame column containing the text data

training_data_x = training_data_x.fillna('')
testing_data_x = testing_data_x.fillna('')
training_data_y = training_data_y.fillna('')
testing_data_y = testing_data_y.fillna('')

#Vectorization
X_train_tfidf = tfidf.fit_transform(training_data_x)
X_test_tfidf = tfidf.transform(testing_data_x)

# %%
conda update --all
# Out:
# Retrieving notices: ...working... done
# Collecting package metadata (current_repodata.json): done
# Solving environment: \
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/noarch::tifffile==2021.7.2=pyhd3eb1b0_2
#   - defaults/osx-arm64::scikit-learn==1.2.2=py39h313beb8_0
#   - defaults/osx-arm64::_ipyw_jlab_nb_ext_conf==0.1.0=py39hca03da5_1
#   - defaults/osx-arm64::scikit-image==0.19.3=py39h313beb8_1
#   - defaults/osx-arm64::contourpy==1.0.5=py39h525c30c_0
#   - defaults/osx-arm64::nbclassic==0.5.5=py39hca03da5_0
#   - defaults/osx-arm64::dask==2023.4.1=py39hca03da5_0
#   - defaults/osx-arm64::qtconsole==5.4.2=py39hca03da5_0
#   - defaults/osx-arm64::navigator-updater==0.3.0=py39hca03da5_0
#   - defaults/osx-arm64::ipykernel==6.19.2=py39h86d0a89_0
#   - defaults/osx-arm64::xarray==2022.11.0=py39hca03da5_0
#   - defaults/osx-arm64::distributed==2023.4.1=py39hca03da5_0
#   - defaults/osx-arm64::imagecodecs==2021.8.26=py39hb8286cb_2
#   - defaults/osx-arm64::bokeh==2.4.3=py39hca03da5_0
#   - defaults/osx-arm64::jupyter==1.0.0=py39hca03da5_8
#   - defaults/osx-arm64::pytables==3.7.0=py39ha5d4e50_1
#   - apple/osx-arm64::tensorflow-deps==2.8.0=0
#   - defaults/osx-arm64::numpy==1.21.5=py39h42add53_3
#   - defaults/osx-arm64::imageio==2.26.0=py39hca03da5_0
#   - defaults/osx-arm64::pywavelets==1.4.1=py39h80987f9_0
#   - defaults/osx-arm64::astropy==5.1=py39heec5a64_0
#   - defaults/osx-arm64::jupyterlab==3.5.3=py39hca03da5_0
#   - defaults/osx-arm64::notebook==6.5.4=py39hca03da5_0
#   - defaults/osx-arm64::pandas==1.5.3=py39h78102c4_0
#   - defaults/osx-arm64::statsmodels==0.13.5=py39hb08c31d_1
#   - defaults/osx-arm64::anaconda==2022.10=py310_0
#   - defaults/osx-arm64::numexpr==2.8.4=py39h79ee842_1
#   - defaults/osx-arm64::panel==0.14.3=py39hca03da5_0
#   - defaults/osx-arm64::conda-build==3.24.0=py39hca03da5_0
#   - defaults/osx-arm64::h5py==3.6.0=py39h7fe8675_0
#   - defaults/osx-arm64::intake==0.6.8=py39hca03da5_0
#   - defaults/osx-arm64::holoviews==1.15.4=py39hca03da5_0
#   - defaults/osx-arm64::jupyter_console==6.6.3=py39hca03da5_0
#   - defaults/osx-arm64::bottleneck==1.3.5=py39heec5a64_0
#   - defaults/osx-arm64::scipy==1.10.1=py39h9d039d2_1
#   - defaults/osx-arm64::datashape==0.5.4=py39hca03da5_1
#   - defaults/osx-arm64::patsy==0.5.3=py39hca03da5_0
#   - defaults/osx-arm64::seaborn==0.12.2=py39hca03da5_0
#   - defaults/osx-arm64::matplotlib-base==3.7.1=py39h78102c4_1
#   - defaults/osx-arm64::xlwings==0.27.15=py39hca03da5_0
#   - defaults/osx-arm64::matplotlib==3.7.1=py39hca03da5_1
#   - defaults/osx-arm64::anaconda-navigator==2.4.0=py39hca03da5_0
#   - defaults/osx-arm64::pyerfa==2.0.0=py39h1a28f6b_0
#   - defaults/osx-arm64::datashader==0.14.4=py39hca03da5_0
#   - defaults/osx-arm64::ipywidgets==8.0.4=py39hca03da5_0
#   - defaults/osx-arm64::numba==0.56.4=py39h78102c4_0
#   - defaults/osx-arm64::hvplot==0.8.2=py39hca03da5_0
#   - defaults/osx-arm64::bkcharts==0.2=py39hca03da5_1
#   - defaults/osx-arm64::gensim==4.3.0=py39h78102c4_0
# failed with repodata from current_repodata.json, will retry with next repodata source.
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): done
# Solving environment: -
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/noarch::tifffile==2021.7.2=pyhd3eb1b0_2
#   - defaults/osx-arm64::scikit-learn==1.2.2=py39h313beb8_0
#   - defaults/osx-arm64::_ipyw_jlab_nb_ext_conf==0.1.0=py39hca03da5_1
#   - defaults/osx-arm64::scikit-image==0.19.3=py39h313beb8_1
#   - defaults/osx-arm64::contourpy==1.0.5=py39h525c30c_0
#   - defaults/osx-arm64::nbclassic==0.5.5=py39hca03da5_0
#   - defaults/osx-arm64::dask==2023.4.1=py39hca03da5_0
#   - defaults/osx-arm64::qtconsole==5.4.2=py39hca03da5_0
#   - defaults/osx-arm64::navigator-updater==0.3.0=py39hca03da5_0
#   - defaults/osx-arm64::ipykernel==6.19.2=py39h86d0a89_0
#   - defaults/osx-arm64::xarray==2022.11.0=py39hca03da5_0
#   - defaults/osx-arm64::distributed==2023.4.1=py39hca03da5_0
#   - defaults/osx-arm64::imagecodecs==2021.8.26=py39hb8286cb_2
#   - defaults/osx-arm64::bokeh==2.4.3=py39hca03da5_0
#   - defaults/osx-arm64::jupyter==1.0.0=py39hca03da5_8
#   - defaults/osx-arm64::pytables==3.7.0=py39ha5d4e50_1
#   - apple/osx-arm64::tensorflow-deps==2.8.0=0
#   - defaults/osx-arm64::numpy==1.21.5=py39h42add53_3
#   - defaults/osx-arm64::imageio==2.26.0=py39hca03da5_0
#   - defaults/osx-arm64::pywavelets==1.4.1=py39h80987f9_0
#   - defaults/osx-arm64::astropy==5.1=py39heec5a64_0
#   - defaults/osx-arm64::jupyterlab==3.5.3=py39hca03da5_0
#   - defaults/osx-arm64::notebook==6.5.4=py39hca03da5_0
#   - defaults/osx-arm64::pandas==1.5.3=py39h78102c4_0
#   - defaults/osx-arm64::statsmodels==0.13.5=py39hb08c31d_1
#   - defaults/osx-arm64::anaconda==2022.10=py310_0
#   - defaults/osx-arm64::numexpr==2.8.4=py39h79ee842_1
#   - defaults/osx-arm64::panel==0.14.3=py39hca03da5_0
#   - defaults/osx-arm64::conda-build==3.24.0=py39hca03da5_0
#   - defaults/osx-arm64::h5py==3.6.0=py39h7fe8675_0
#   - defaults/osx-arm64::intake==0.6.8=py39hca03da5_0
#   - defaults/osx-arm64::holoviews==1.15.4=py39hca03da5_0
#   - defaults/osx-arm64::jupyter_console==6.6.3=py39hca03da5_0
#   - defaults/osx-arm64::bottleneck==1.3.5=py39heec5a64_0
#   - defaults/osx-arm64::scipy==1.10.1=py39h9d039d2_1
#   - defaults/osx-arm64::datashape==0.5.4=py39hca03da5_1
#   - defaults/osx-arm64::patsy==0.5.3=py39hca03da5_0
#   - defaults/osx-arm64::seaborn==0.12.2=py39hca03da5_0
#   - defaults/osx-arm64::matplotlib-base==3.7.1=py39h78102c4_1
#   - defaults/osx-arm64::xlwings==0.27.15=py39hca03da5_0
#   - defaults/osx-arm64::matplotlib==3.7.1=py39hca03da5_1
#   - defaults/osx-arm64::anaconda-navigator==2.4.0=py39hca03da5_0
#   - defaults/osx-arm64::pyerfa==2.0.0=py39h1a28f6b_0
#   - defaults/osx-arm64::datashader==0.14.4=py39hca03da5_0
#   - defaults/osx-arm64::ipywidgets==8.0.4=py39hca03da5_0
#   - defaults/osx-arm64::numba==0.56.4=py39h78102c4_0
#   - defaults/osx-arm64::hvplot==0.8.2=py39hca03da5_0
#   - defaults/osx-arm64::bkcharts==0.2=py39hca03da5_1
#   - defaults/osx-arm64::gensim==4.3.0=py39h78102c4_0
# done
#
# ## Package Plan ##
#
#   environment location: /Users/student/anaconda3
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     certifi-2023.5.7           |   py39hca03da5_0         153 KB
#     ------------------------------------------------------------
#                                            Total:         153 KB
#
# The following NEW packages will be INSTALLED:
#
#   numpy-base         pkgs/main/osx-arm64::numpy-base-1.21.5-py39hadd41eb_3
#   psutil             pkgs/main/osx-arm64::psutil-5.9.0-py39h1a28f6b_0
#
# The following packages will be UPDATED:
#
#   certifi                          2022.12.7-py39hca03da5_0 --> 2023.5.7-py39hca03da5_0
#
#
#
# Downloading and Extracting Packages
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade threadpoolctl
# Out:
# Requirement already satisfied: threadpoolctl in /Users/student/anaconda3/lib/python3.9/site-packages (2.2.0)
# Collecting threadpoolctl
#   Downloading threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# Installing collected packages: threadpoolctl
#   Attempting uninstall: threadpoolctl
#     Found existing installation: threadpoolctl 2.2.0
#     Uninstalling threadpoolctl-2.2.0:
#       Successfully uninstalled threadpoolctl-2.2.0
# Successfully installed threadpoolctl-3.1.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# %%
knn = KNeighborsClassifier(n_neighbors=3)  # You can adjust the value of n_neighbors as per your requirements
knn.fit(X_train_tfidf, training_data_y)
y_pred = knn.predict(X_test_tfidf)

# Evaluate the accuracy of the model
accuracy = accuracy_score(testing_data_y, y_pred)

# %%
accuracy
# Out:
# 0.285

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score

# Calculate precision
precision = precision_score(testing_data_y, y_pred, average='macro')

# Calculate recall
recall = recall_score(testing_data_y, y_pred, average='macro')

# Calculate F1-score
f1 = f1_score(testing_data_y, y_pred, average='macro')

# Calculate accuracy
accuracy = accuracy_score(testing_data_y, y_pred)

# Print the metrics
print("For KNN Model:")
print("Precision: ", precision)
print("Recall: ", recall)
print("F1-score: ", f1)
print("Accuracy: ", accuracy)
# Out:
# For KNN Model:
# Precision:  0.4905810487211447
# Recall:  0.2731221677235438
# F1-score:  0.27523240794016923
# Accuracy:  0.285
# /Users/student/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/student/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score

# Create an instance of the Decision Tree classifier
dt = DecisionTreeClassifier()

# Fit the Decision Tree model on the training data
dt.fit(X_train_tfidf, training_data_y)

# Make predictions on the test data
y_pred = dt.predict(X_test_tfidf)

# Calculate precision
precision = precision_score(testing_data_y, y_pred, average='macro')

# Calculate recall
recall = recall_score(testing_data_y, y_pred, average='macro')

# Calculate F1-score
f1 = f1_score(testing_data_y, y_pred, average='macro')

# Calculate accuracy
accuracy = accuracy_score(testing_data_y, y_pred)

# Print the metrics
print("For Decision Tree Model:")
print("Precision: ", precision)
print("Recall: ", recall)
print("F1-score: ", f1)
print("Accuracy: ", accuracy)
# Out:
# For Decision Tree Model:
# Precision:  0.5052398516513619
# Recall:  0.41935758462476114
# F1-score:  0.4437939615544408
# Accuracy:  0.9266
# /Users/student/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/student/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score

# Create an instance of the Random Forest classifier
rf = RandomForestClassifier()

# Fit the Random Forest model on the training data
rf.fit(X_train_tfidf, training_data_y)

# Make predictions on the test data
y_pred = rf.predict(X_test_tfidf)

# Calculate precision
precision = precision_score(testing_data_y, y_pred, average='macro')

# Calculate recall
recall = recall_score(testing_data_y, y_pred, average='macro')

# Calculate F1-score
f1 = f1_score(testing_data_y, y_pred, average='macro')

# Calculate accuracy
accuracy = accuracy_score(testing_data_y, y_pred)

# Print the metrics
print("For Random Forest Model:")
print("Precision: ", precision)
print("Recall: ", recall)
print("F1-score: ", f1)
print("Accuracy: ", accuracy)
# Out:
# For Random Forest Model:
# Precision:  0.5835614331402217
# Recall:  0.4436575597763173
# F1-score:  0.46984747375966307
# Accuracy:  0.953
# /Users/student/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score

# Create an instance of the Multinomial Naive Bayes classifier
nb = MultinomialNB()

# Fit the Multinomial Naive Bayes model on the training data
nb.fit(X_train_tfidf, training_data_y)

# Make predictions on the test data
y_pred = nb.predict(X_test_tfidf)

# Calculate precision
precision = precision_score(testing_data_y, y_pred, average='macro')

# Calculate recall
recall = recall_score(testing_data_y, y_pred, average='macro')

# Calculate F1-score
f1 = f1_score(testing_data_y, y_pred, average='macro')

# Calculate accuracy
accuracy = accuracy_score(testing_data_y, y_pred)

# Print the metrics
print("For Multinomial Naive Bayes Classifier Model:")
print("Precision: ", precision)
print("Recall: ", recall)
print("F1-score: ", f1)
print("Accuracy: ", accuracy)
# Out:
# For Multinomial Naive Bayes Classifier Model:
# Precision:  0.31105397935666707
# Recall:  0.2449513111639507
# F1-score:  0.2583955770998612
# Accuracy:  0.9213
# /Users/student/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
